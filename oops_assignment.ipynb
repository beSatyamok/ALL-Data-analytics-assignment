# %% [markdown]
# Python OOPs Questions
#
#
# ---
#
#
#
# 1.What is object oreinted programing(OOP)?
#
# Ans: OOP is a programming paradigm that organizes code into objects, which combine data (attributes) and behavior (methods).
# It helps make code modular, reusable, and easier to maintain.

# %%
class Dog:
    def sound(self):
        return "Bark"

class Cat:
    def sound(self):
        return "Meow"

for animal in [Dog(), Cat()]:
    print(animal.sound())

# %% [markdown]
# 2. What is  class in oop?
#
# Ans: A class is like a plan or design, and an object is the actual thing built from that plan.
#
# For example:
#
# * A class could be Car.
#
# * An object could be my_car = Car("Toyota", "Red").
#
# * Syntax in Python

# %%
class Car:
    # Constructor (used to initialize object data)
    def __init__(self, brand, color):
        self.brand = brand    # Attribute
        self.color = color    # Attribute

    # Method (behavior)
    def show_details(self):
        print(f"Car brand: {self.brand}, Color: {self.color}")

# %% [markdown]
# * Creating an Object (Instance)

# %%
my_car = Car("Toyota", "Red")
my_car.show_details()

# %% [markdown]
# 3. What is an object in oop?
#
# Ans: An object is an instance of a class.
#
# It represents a real-world entity created from a class blueprint.

# %%
class Car:
    def __init__(self, brand, color):
        self.brand = brand
        self.color = color

    def show_details(self):
        print(f"Car brand: {self.brand}, Color: {self.color}")

# Creating objects (instances)
car1 = Car("Toyota", "Red")
car2 = Car("Honda", "Blue")

# Accessing object methods
car1.show_details()
car2.show_details()

# %% [markdown]
# 4. What is difference between  abstraction and incapsulation?
#
# Ans:
# | Concept           | Description                                                                                 |
# | ----------------- | ------------------------------------------------------------------------------------------- |
# | **Abstraction**   | Hides complex details and shows only the necessary features.                                |
# | **Encapsulation** | Bundles data and methods into one unit and restricts direct access using private variables. |

# %%
# Abstraction Example
from abc import ABC, abstractmethod

class Car(ABC):
    @abstractmethod
    def start(self):
        pass

class Tesla(Car):
    def start(self):
        print("Starting car with electric power...")

# User only knows 'start', not how it works
car = Tesla()
car.start()

# %%
# Encapsulation Example
class Car:
    def __init__(self):
        self.__engine_status = "off"

    def start(self):
        self.__engine_status = "on"
        print("Car started")

    def get_status(self):
        return self.__engine_status

car = Car()
car.start()
print(car.get_status())

# %% [markdown]
# 5. What are dunder methods in python?
#
# Ans: Dunder methods in Python (short for “Double UNDERscore” methods) are special built-in methods that start and end with double underscores — for example, __init__, __str__, __len__, etc.
#
# They are also called magic methods or special methods.
# Python uses them internally to make objects behave like built-in types.
#
# Meaning:
#
# * “Dunder” = Double UNDERscore
#
# Purpose:
#
# * Dunder methods let you customize the behavior of your own classes so they can:
#
# * Work with Python’s built-in operators
#
# * Support built-in functions like len(), str(), print(), etc.
#
# * Define how objects are created, compared, or represented
#
# * Common Dunder Methods and Their Uses
#
# | **Method**                        | **Purpose**                                       | **Example**          |
# | --------------------------------- | ------------------------------------------------- | -------------------- |
# | `__init__(self)`                  | Initializes a new object (constructor)            | `Car("Tesla")`       |
# | `__str__(self)`                   | Defines the string representation (for `print()`) | `print(obj)`         |
# | `__repr__(self)`                  | Developer-friendly representation                 | `repr(obj)`          |
# | `__len__(self)`                   | Defines behavior of `len(obj)`                    | `len(obj)`           |
# | `__add__(self, other)`            | Defines `+` operator behavior                     | `obj1 + obj2`        |
# | `__eq__(self, other)`             | Defines equality check `==`                       | `obj1 == obj2`       |
# | `__lt__(self, other)`             | Defines less-than `<`                             | `obj1 < obj2`        |
# | `__getitem__(self, index)`        | Enables indexing                                  | `obj[index]`         |
# | `__setitem__(self, index, value)` | Enables assignment by index                       | `obj[index] = value` |
# | `__delitem__(self, index)`        | Defines behavior for `del obj[index]`             | `del obj[index]`     |
# | `__call__(self)`                  | Makes an object callable like a function          | `obj()`              |
# | `__iter__(self)`                  | Makes an object iterable                          | `for i in obj:`      |
# | `__next__(self)`                  | Returns next value in iteration                   | `next(obj)`          |

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"({self.x}, {self.y})"

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

p1 = Point(2, 3)
p2 = Point(4, 5)

print(p1)
print(p1 + p2)

# %% [markdown]
# 6. Explain the concept of inheritence in oop.
#
# Ans: Inheritance allows a class (child) to derive properties and methods from another class (parent).
# It promotes code reuse.

# %%
class Animal:
    def speak(self):
        print("Animal speaks")

class Dog(Animal):
    def speak(self):
        print("Dog barks")

# %% [markdown]
# 7. What is polymorphism in oop.
#
# Ans: Polymorphism means "many forms" — the same method can behave differently depending on the object.

# %%
class Dog:
    def speak(self):
        return "Woof!"

class Cat:
    def speak(self):
        return "Meow!"

# Polymorphism in action
for animal in [Dog(), Cat()]:
    print(animal.speak())

# %% [markdown]
# 8. How is an encapsulation achieved in Python?
#
# Ans: Encapsulation in Python is the process of wrapping data (variables) and methods (functions) into a single unit — usually a class — and restricting direct access to some of the object’s internal data.

# %% [markdown]
# * How Encapsulation is Achieved in Python
#
# Encapsulation is achieved using access modifiers that control how attributes and methods can be accessed:
#
# | **Access Modifier** | **Syntax**                       | **Meaning**                                        | **Accessibility**            |
# | ------------------- | -------------------------------- | -------------------------------------------------- | ---------------------------- |
# | **Public**          | `variable`                       | Can be accessed from anywhere                      | Inside and outside the class |
# | **Protected**       | `_variable` (single underscore)  | Meant for internal use (not enforced strictly)     | Accessible in subclasses     |
# | **Private**         | `__variable` (double underscore) | Cannot be accessed directly from outside the class | Only inside the class        |

# %%
class Person:
    def __init__(self):
        self.__age = 20   # private
    def get_age(self):
        return self.__age

# %% [markdown]
# 9. What is constructor in  python?
#
# Ans: A constructor in Python is a special method that is automatically called when a new object of a class is created.
# It is mainly used to initialize the object’s attributes (assign values when the object is created).
#
# * In Python, the constructor method is:
#
# * It is a dunder (double underscore) method.
#
# * The word “init” stands for initialize.
#
# * It is automatically invoked when you create an object of the class.

# %%
class Student:
    def __init__(self, name, age):  # Constructor
        self.name = name
        self.age = age

# Creating an object of the class
s1 = Student("Alice", 20)

print(s1.name)  # Output: Alice
print(s1.age)   # Output: 20

# %% [markdown]
# 10. What are classic and static methods in  python.
#
# Ans:
# | Method Type         | Decorator       | Use                                                           |
# | ------------------- | --------------- | ------------------------------------------------------------- |
# | **Instance Method** | —               | Works on specific objects (`self`)                            |
# | **Classic Method**    | `@classmethod`  | Works on the class itself (`cls`)                             |
# | **Static Method**   | `@staticmethod` | Doesn’t need `self` or `cls`; utility function inside a class |

# %% [markdown]
# 11. What is  method overloading in python?
#
# Ans: In Python, method overloading is the ability to define multiple methods with the same name but different parameters in a class. However, Python does not support traditional method overloading like Java or C++. If you define multiple methods with the same name, the last definition overrides the previous ones.

# %%
class Demo:
    def greet(self, name):
        print(f"Hello {name}!")

    def greet(self):
        print("Hello!")

d = Demo()
# d.greet("Alice")  # This will cause an error
d.greet()           # Works, prints: Hello!

# %% [markdown]
# 12. What is method overriding in oop?
#
# Ans: When a child class defines a method with the same name as in the parent class, it overrides the parent’s version.

# %%
class Animal:
    def sound(self):
        print("Animals make different sounds")

class Dog(Animal):
    def sound(self):  # overriding the parent method
        print("Dog barks")

# Create objects
a = Animal()
d = Dog()

a.sound()
d.sound()

# %% [markdown]
# 13. What is a property decorator in python?
#
# Ans.A property decorator in Python is a built-in feature that allows you to define getter, setter, and deleter methods for class attributes — making it possible to access methods like attributes while still controlling their behavior.It’s mainly used to implement encapsulation and data hiding in a Pythonic way.

# %%
class Circle:
    def __init__(self, r):
        self._r = r
    @property
    def area(self):
        return 3.14 * self._r**2

# %% [markdown]
# 14. What is polymorphism important in oop?
#
# Ans: It increases flexibility and reusability, allowing the same interface to handle different data types or classes.

# %%
class Bird:
    def speak(self):
        return "Some generic bird sound"

class Parrot(Bird):
    def speak(self):
        return "Squawk!"

class Sparrow(Bird):
    def speak(self):
        return "Chirp!"

# Polymorphism in action
for bird in [Parrot(), Sparrow(), Bird()]:
    print(bird.speak())

# %% [markdown]
# 15. What is an abstract class in python.
#
# Ans: An abstract class cannot be instantiated and may contain abstract methods (declared but not defined).
# Defined using the abc module.

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# %% [markdown]
# 16. What are the advantage of oop.
#
# Ans: The advantages of Object-Oriented Programming (OOP) come from its ability to organize code around objects — which combine data (attributes) and behavior (methods).
#
# 1. Reusability
#
# * OOP promotes code reuse through inheritance.
#
# * You can create a base class and reuse its code in multiple subclasses.
#
# * Example: A Vehicle class can be reused by Car, Bike, and Bus classes.
#
#  2. Modularity
#
# * Code is organized into classes and objects, making it modular.
#
# * Each class handles a specific part of the program, making it easier to maintain or debug.
#
#  3. Encapsulation
#
# * OOP allows hiding internal details of an object and only exposing necessary parts through public methods.
#
# * This helps protect data and prevent accidental modifications.
#
#  4. Abstraction
#
# * OOP allows you to focus on what an object does, not how it does it.
#
# * Complex implementation details are hidden, making the code cleaner and easier to use.
#
#  5. Polymorphism
#
# * OOP enables different objects to respond to the same function call in their own way.
#
# * Example: Both Dog and Cat classes can have a method make_sound(), but each produces a different result.
#
#  6. Maintainability and Scalability
#
# * Because of modularity, it’s easier to update or extend parts of the code without affecting the whole program.
#
# * Ideal for large and complex projects.
#
#  7. Real-world Modeling
#
# * OOP models real-world entities as objects, making it more intuitive and easier to understand.
#
# * Summary Table

# %% [markdown]
# 17. What is difference between a class variable  and a instance variable.
#
# Ans:
# | Type                  | Shared?               | Defined where?                |
# | --------------------- | --------------------- | ----------------------------- |
# | **Class Variable**    | Shared by all objects | Inside class, outside methods |
# | **Instance Variable** | Unique per object     | Inside `__init__()`           |

# %% [markdown]
# 18. What is multiple inheritence in python.
#
# Ans: Multiple Inheritance in Python is a feature where a class can inherit from more than one parent class. This allows the child class to combine behaviors and attributes from multiple parent classes.
#
# Key Points:
#
# * Python supports multiple inheritance directly.
#
# * The child class inherits all methods and attributes from its parent classes.
#
# * If multiple parents have methods with the same name, Python uses the Method Resolution Order (MRO) to determine which method to call.
#
# * Be careful of the “diamond problem”, which MRO helps to resolve.

# %%
class A: pass
class B: pass
class C(A, B): pass

# %% [markdown]
# 19. Explain the purpose of "__str__'and'__repr__''methods in python.
#
# Ans.In Python, __str__ and __repr__ are special (dunder) methods used to control how objects are represented as strings. They are similar but have different purposes:
#
# 1.  str method
#
# * Purpose: Provides a user-friendly string representation of an object, meant to be readable.
#
# * Used by: The str() function and print() function.
#
# Example:

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name}, {self.age} years old"

p = Person("Alice", 30)
print(p)
print(str(p))

# %% [markdown]
# 2.  __repr__ method
#
# * Purpose: Provides an unambiguous string representation of an object, meant for developers. Ideally, it should be possible to recreate the object from this string.
#
# * Used by: The repr() function, and when you inspect objects in the Python shell.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __repr__(self):
        return f"Person('{self.name}', {self.age})"

p = Person("Alice", 30)
print(repr(p))

# %% [markdown]
# 20 What is the significance  of the 'super()' function in python.
#
# Ans.super() allows you to call methods from the parent class in the child class.

# %%
class Child(Parent):
    def __init__(self):
        super().__init__()

# %% [markdown]
# 21. What is the significance of the __del__ method in python.
#
# An: __del__ is called when an object is deleted or destroyed, used for cleanup (like closing files).

# %%
class FileHandler:
    def __init__(self, filename):
        self.file = open(filename, 'w')
        print("File opened")

    def __del__(self):
        self.file.close()
        print("File closed")

f = FileHandler("test.txt")
del f   # Manually deleting object triggers __del__

# %% [markdown]
# 22.  What is difference between @static method and @class method in python.
#
# Ans:
# | Feature                | `@staticmethod` | `@classmethod`               |
# | ---------------------- | --------------- | ---------------------------- |
# | Access to `self`/`cls` | No              | Yes (`cls`)                  |
# | Purpose                | Utility method  | Operates on class-level data |

# %% [markdown]
# 23. How does polymorphism work in python with inheritence?
#
# Ans: When a child class overrides a parent method, Python decides at runtime which method to call depending on the object’s type.

# %%
class Animal:
    def sound(self):
        return "Some generic sound"

class Dog(Animal):
    def sound(self):
        return "Bark"

class Cat(Animal):
    def sound(self):
        return "Meow"

# Using polymorphism
animals = [Dog(), Cat(), Animal()]

for animal in animals:
    print(animal.sound())

# %% [markdown]
# * How it works:
#
# 1 The Animal class defines a general method sound().
#
# 2 Dog and Cat inherit from Animal but override the sound() method.
#
# 3 When we loop through the animals list, Python automatically calls the appropriate version of sound() depending on the object’s class — this is runtime polymorphism.
#
# * Key Points:
#
# 1 Polymorphism works through method overriding in inheritance.
#
# 2 The same method name behaves differently for different derived classes.
#
# 3 It helps in code reusability and flexibility.

# %% [markdown]
# 24. What is method chaining in python  oop?
#
# Ans: Calling multiple methods in a single line, where each method returns self.

# %%
class Demo:
    def a(self): print("A"); return self
    def b(self): print("B"); return self

Demo().a().b()

# %% [markdown]
# 25 What is  the  purpose of the __call__ method in python?
#
# Ans:  Makes an object callable like a function.

# %%
class Add:
    def __call__(self, a, b):
        return a + b

adder = Add()
print(adder(2, 3))  # behaves like a function

# %% [markdown]
# **PRACTICAL QUESTIONS**
#
# ---

# %%
' 1. Create a parent class animal with a method speak() that prints a generic message create a child class dog that overrides the speak() method to print"Bark".'

# Parent class
class Animal:
    def speak(self):
        print("The animal makes a sound")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark")

# Create objects
a = Animal()
d = Dog()

# Call the methods
a.speak()
d.speak()

# %%
' 2. Write an program to create an abstract class shape with a method area().Drive classes circle and rectangle from it and implement the area () method  in both.'

from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Child class Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius * self.radius

# Child class Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Create objects
c = Circle(5)
r = Rectangle(4, 6)

# Display areas
print("Area of Circle:", c.area())
print("Area of Rectangle:", r.area())

# %%
' 3. Inplement a multilevel inheritence scenario where a class vehicle has an attribute type.Drive a class  car and further drive a class electric car that adds a battery attribute.'

# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_info(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Derived class from Vehicle
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)   # call Vehicle constructor
        self.brand = brand

    def display_info(self):
        super().display_info()
        print(f"Brand: {self.brand}")

# Further derived class from Car
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)   # call Car constructor
        self.battery_capacity = battery_capacity

    def display_info(self):
        super().display_info()
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Create object of ElectricCar
e_car = ElectricCar("Four Wheeler", "Tesla", 75)

# Display information
e_car.display_info()

# %%
' 4. Demonstrate polymorphism by creating a base class bird with a method fly ().Create two derived classes sparrow and penguin that override the fly ()method .'

# Base class
class Bird:
    def fly(self):
        print("Birds can fly... generally.")

# Derived class Sparrow
class Sparrow(Bird):
    def fly(self):
        print("Sparrow can fly high in the sky.")

# Derived class Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly, but it can swim well.")

# Create objects
b1 = Sparrow()
b2 = Penguin()

# Polymorphism: same method name, different behavior
for bird in (b1, b2):
    bird.fly()

# %%
' 5. Write a program to demonstrate encapsulation by creating a class bank account with private attributes balance and methods to deposit withdraw and check balance.'

# Class demonstrating encapsulation
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # Private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: ${amount}")
        else:
            print("Deposit amount must be positive.")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.__balance:
                self.__balance -= amount
                print(f"Withdrawn: ${amount}")
            else:
                print("Insufficient balance!")
        else:
            print("Withdrawal amount must be positive.")

    # Method to check balance
    def check_balance(self):
        print(f"Current Balance: ${self.__balance}")


# Usage
account = BankAccount(1000)

account.deposit(500)
account.withdraw(200)
account.check_balance()

# Trying to access private attribute directly (will fail)
# print(account.__balance)  # AttributeError

# %%
' 6. Demonstrate run time polymorphism using a method play () in a base class instrument. Derive classes guitar and piano that implement their own version of play().'

# Base class
class Instrument:
    def play(self):
        print("Playing some instrument...")

# Derived class Guitar
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar!")

# Derived class Piano
class Piano(Instrument):
    def play(self):
        print("Playing the piano keys!")

# Runtime polymorphism
def perform(instrument):
    instrument.play()   # Calls the appropriate play() based on object type

# Create objects
g = Guitar()
p = Piano()

# Demonstrate runtime polymorphism
perform(g)
perform(p)

# %%
' 7. Create a class math operations with a class method add_numbers() to add two numbers and a static method substract_numbers()to substract two numbers.'

class MathOperations:
    # Class method to add two numbers
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method to subtract two numbers
    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Using class method
sum_result = MathOperations.add_numbers(10, 5)
print("Sum:", sum_result)

# Using static method
sub_result = MathOperations.subtract_numbers(10, 5)
print("Difference:", sub_result)

# %%
' 8. implement a class person with a class method to count a  total numbers of persons created.'

class Person:
    # Class variable to keep count of persons
    total_persons = 0

    def __init__(self, name):
        self.name = name
        # Increase the count whenever a new person is created
        Person.total_persons += 1

    # Class method to get total number of persons
    @classmethod
    def get_total_persons(cls):
        return cls.total_persons


# Creating objects of Person
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

# Using class method to get total number of persons
print("Total persons created:", Person.get_total_persons())

# %%
' 9. Write a class fraction with attributes numerator and denominator.Override the str method to display the fraction as numerator\ denominator.'

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Overriding the __str__ method
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# Creating objects of Fraction
f1 = Fraction(3, 4)
f2 = Fraction(7, 8)

# Displaying fractions
print(f1)
print(f2)

# %%
' 10. Demonstrate operator  overloading by creating a class  vector  and overriding the  add method  to add two  vectors.'

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overloading the + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # Overriding __str__ method for clean output
    def __str__(self):
        return f"({self.x}, {self.y})"


# Creating two vectors
v1 = Vector(2, 3)
v2 = Vector(4, 5)

# Adding two vectors using overloaded +
v3 = v1 + v2

# Displaying the result
print("Vector 1:", v1)
print("Vector 2:", v2)
print("Resultant Vector:", v3)

# %%
' 11. Create a class person with attributes name and  age. Add a method greet() that prints hello my name is {name}and i am {age} year old.'

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


# Creating objects of Person
p1 = Person("Alice", 25)
p2 = Person("Bob", 30)

# Calling the greet method
p1.greet()
p2.greet()

# %%
' 12. Implement a class student with attributes name and grades. Create a method average_grade() to compute the  average of the grades.'

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # Expecting a list of numbers

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

# Example usage
student1 = Student("Alice", [85, 90, 78, 92])
print(f"Name: {student1.name}")
print(f"Grades: {student1.grades}")
print(f"Average Grade: {student1.average_grade():.2f}")

# %%
' 13. Create a class rectangle with methods set_dimensions ()to set the dimensions and area () to calculate the area.'

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example usage
rect = Rectangle()
rect.set_dimensions(5, 3)
print(f"Length: {rect.length}, Width: {rect.width}")
print(f"Area of rectangle: {rect.area()}")

# %%
' 14.  Create a  class employ with a method calculate_salary () that computes the salary based on hours worked and  hourly rate. Create  a derived class manager that adds a bonus to the salary.'

# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# Example usage
emp = Employee("Alice", 40, 20)
mgr = Manager("Bob", 40, 25, 500)

print(f"{emp.name}'s Salary: ${emp.calculate_salary()}")
print(f"{mgr.name}'s Salary: ${mgr.calculate_salary()}")

# %%
' 15. Create a class product with  attributes name price and quantity. implement a method total _ price () that calculates the total price of the product.'

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# Example usage
product1 = Product("Laptop", 800, 3)
print(f"Product: {product1.name}")
print(f"Unit Price: ${product1.price}")
print(f"Quantity: {product1.quantity}")
print(f"Total Price: ${product1.total_price()}")

# %%
' 16. Create a class animal method with an abstract method sound(). create a two derived classes cow and sheep that implement the sound() method.'

from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class Cow
class Cow(Animal):
    def sound(self):
        return "Moo"

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        return "Baa"

# Example usage
cow = Cow()
sheep = Sheep()

print(f"Cow says: {cow.sound()}")
print(f"Sheep says: {sheep.sound()}")

# %%
' 17. Create a class book with attribute title autor and year_published. Add a method get_ book_into() that returns a formatted string with the books details.'

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


# Example usage
book1 = Book("To Kill a Mockingbird", "Harper Lee", 1960)
print(book1.get_book_info())

# %%
' 18. Create a class house with attributes address and price .Create a derived class mansion that adds on attributes  numbers_ of_ the rooms.'

# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def get_info(self):
        return f"Address: {self.address}, Price: ${self.price}"


# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def get_info(self):
        base_info = super().get_info()
        return f"{base_info}, Number of Rooms: {self.number_of_rooms}"


# Example usage
house1 = House("123 Main St", 250000)
mansion1 = Mansion("456 Luxury Ave", 1500000, 10)

print(house1.get_info())
print(mansion1.get_info())
